# %%
import pandas as pd
df = pd.read_csv(r""C:\xampp\htdocs\Cricket\teams-players\model\Batting data.csv"")
df
# Out:
#       id              Name  Matches  Overs Bowled  Wickets  Runs Given  \
# 0      1      Iosep Zealey        8             7       10          40
# 1      2      Oneida Liley        6             7        6          38
# 2      3       Jarred Tabb        7             6        7          62
# 3      4    Jessey Devereu        7             5        9          77
# 4      5  Kiersten Warrick        8             6       11          77
# ..   ...               ...      ...           ...      ...         ...
# 595  596      Wylie Werner        5             5        1          76
# 596  597       Alvie Sketh        6             6       10          60
# 597  598   Annabell Dirand        8             7        3          68
# 598  599  Tobi Janicijevic        8             5       12          39
# 599  600  Barnebas Shovlar        7             6       12          74
#
#      Economy  Average  Performance Wickets 5  Performance Wickets 4  \
# 0       5.04        4                      1                      1
# 1       5.91        6                      3                      3
# 2       8.35        8                      3                      3
# 3       8.60        8                      2                      1
# 4       7.25        7                      2                      3
# ..       ...      ...                    ...                    ...
# 595     8.35       76                      4                      1
# 596     8.50        6                      1                      2
# 597     7.49       22                      4                      3
# 598     8.86        3                      2                      3
# 599     5.08        6                      2                      2
#
#      Performance Wickets 3  Performance Wickets 2  Performance Wickets 1
# 0                        3                      1                      6
# 1                        4                      4                      1
# 2                        4                      4                      2
# 3                        2                      1                      2
# 4                        2                      3                      1
# ..                     ...                    ...                    ...
# 595                      4                      3                      2
# 596                      2                      3                      5
# 597                      4                      2                      2
# 598                      3                      4                      6
# 599                      4                      1                      6
#
# [600 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['id', 'Name', 'Matches', 'Runs', 'Bowls', 'Average',
#        'Performance Runs 5', 'Performance Runs 4', 'Performance Runs 3',
#        'Performance Runs 2', 'Performance Runs 1'],
#       dtype='object')

# %%
#checking for missing values
df.isnull().sum()
# Out:
# id                    0
# Name                  0
# Matches               0
# Runs                  0
# Bowls                 0
# Average               0
# Performance Runs 5    0
# Performance Runs 4    0
# Performance Runs 3    0
# Performance Runs 2    0
# Performance Runs 1    0
# dtype: int64

# %%
df.dtypes
# Out:
# id                     int64
# Name                  object
# Matches                int64
# Runs                   int64
# Bowls                  int64
# Average                int64
# Performance Runs 5     int64
# Performance Runs 4     int64
# Performance Runs 3     int64
# Performance Runs 2     int64
# Performance Runs 1     int64
# dtype: object

# %%
#checking correlation
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
corr = df.corr()
fig, ax = plt.subplots(figsize=(30, 18))
colormap = sns.diverging_palette(220, 10, as_cmap=True)
dropSelf = np.zeros_like(corr)
dropSelf[np.triu_indices_from(dropSelf)] = True
colormap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=colormap, linewidths=.5, annot=True, fmt=".2f", mask=dropSelf)
plt.title('Crickets - Features Correlations')
plt.show()
